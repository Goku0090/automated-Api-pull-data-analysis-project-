# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'be509dda-4aee-43f5-8577-17cbd4d710c3',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

#NOTE:
# I had to go in and put "jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10"
# Into the Anaconda Prompt to change this to allow to pull data

# If that didn't work try using the local host URL as shown in the video

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd


#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#This normalizes the data and makes it all pretty in a dataframe

df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin             12210
# 1    1027      Ethereum    ETH      ethereum             10331
# 2     825   Tether USDt   USDT        tether            131893
# 3      52           XRP    XRP           xrp              1623
# 4    1839           BNB    BNB           bnb              2565
# 5    5426        Solana    SOL        solana               933
# 6    3408          USDC   USDC      usd-coin             28498
# 7      74      Dogecoin   DOGE      dogecoin              1234
# 8    1958          TRON    TRX          tron              1183
# 9    2010       Cardano    ADA       cardano              1529
# 10  32196   Hyperliquid   HYPE   hyperliquid               105
# 11  20947           Sui    SUI           sui               672
# 12   1975     Chainlink   LINK     chainlink              2020
# 13   3957  UNUS SED LEO    LEO  unus-sed-leo                61
# 14   5805     Avalanche   AVAX     avalanche               920
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2013-08-04T00:00:00.000Z
# 4   2017-07-25T00:00:00.000Z
# 5   2020-04-10T00:00:00.000Z
# 6   2018-10-08T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2017-09-13T00:00:00.000Z
# 9   2017-10-01T00:00:00.000Z
# 10  2024-07-15T10:14:50.000Z
# 11  2022-07-12T08:03:11.000Z
# 12  2017-09-20T00:00:00.000Z
# 13  2019-05-21T00:00:00.000Z
# 14  2020-07-13T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [stablecoin, asset-backed-stablecoin, usd-stab...           NaN
# 3   [medium-of-exchange, enterprise-solutions, xrp...  1.000000e+11
# 4   [marketplace, centralized-exchange, payments, ...           NaN
# 5   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 6   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 7   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 8   [media, payments, tron-ecosystem, layer-1, dwf...           NaN
# 9   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 10  [decentralized-exchange-dex-token, defi, deriv...  1.000000e+09
# 11  [binance-launchpool, coinbase-ventures-portfol...  1.000000e+10
# 12  [platform, defi, oracles, smart-contracts, eth...           NaN
# 13  [marketplace, centralized-exchange, discount-t...           NaN
# 14  [smart-contracts, three-arrows-capital-portfol...  7.157487e+08
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.987517e+07  1.987517e+07            False       NaN         1
# 1         1.207220e+08  1.207220e+08             True       NaN         2
# 2         1.541236e+11  1.560037e+11             True       NaN         3
# 3         5.882165e+10  9.998606e+10            False       NaN         4
# 4         1.408871e+08  1.408871e+08            False       NaN         5
# 5         5.240947e+08  6.024124e+08             True       NaN         6
# 6         6.104014e+10  6.104014e+10            False       NaN         7
# 7         1.495752e+11  1.495752e+11             True       NaN         8
# 8         9.485302e+10  9.485304e+10             True       NaN         9
# 9         3.534213e+10  4.499459e+10            False       NaN        10
# 10        3.339282e+08  9.999939e+08            False       NaN        11
# 11        3.396671e+09  1.000000e+10            False       NaN        12
# 12        6.571000e+08  1.000000e+09            False       NaN        13
# 13        9.232910e+08  9.852395e+08            False       NaN        14
# 14        4.217477e+08  4.567504e+08            False       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap tvl_ratio  \
# 0                                NaN                       NaN      None
# 1                                NaN                       NaN      None
# 2                                NaN                       NaN      None
# 3                                NaN                       NaN      None
# 4                                NaN                       NaN      None
# 5                                NaN                       NaN      None
# 6                       6.090122e+10              6.088772e+10      None
# 7                                NaN                       NaN      None
# 8                                NaN                       NaN      None
# 9                                NaN                       NaN      None
# 10                      3.339317e+08              1.159023e+10      None
# 11                      3.396671e+09              1.082459e+10      None
# 12                               NaN                       NaN      None
# 13                               NaN                       NaN      None
# 14                               NaN                       NaN      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2025-06-06T16:44:00.000Z    104952.153134          6.171259e+10
# 1   2025-06-06T16:45:00.000Z      2504.010393          2.732268e+10
# 2   2025-06-06T16:44:00.000Z         1.000745          9.838282e+10
# 3   2025-06-06T16:45:00.000Z         2.175606          3.488523e+09
# 4   2025-06-06T16:44:00.000Z       647.357612          2.073938e+09
# 5   2025-06-06T16:44:00.000Z       150.724018          4.335845e+09
# 6   2025-06-06T16:45:00.000Z         0.999778          1.465000e+10
# 7   2025-06-06T16:44:00.000Z         0.181076          2.072623e+09
# 8   2025-06-06T16:44:00.000Z         0.279090          9.093318e+08
# 9   2025-06-06T16:45:00.000Z         0.666983          9.857578e+08
# 10  2025-06-06T16:44:00.000Z        34.708375          3.920814e+08
# 11  2025-06-06T16:45:00.000Z         3.186822          1.299446e+09
# 12  2025-06-06T16:45:00.000Z        13.554567          5.099515e+08
# 13  2025-06-06T16:44:00.000Z         9.014225          4.837891e+06
# 14  2025-06-06T16:45:00.000Z        19.712787          4.634271e+08
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                       42.5600                     0.196598
# 1                       49.1069                     0.064906
# 2                       47.2203                    -0.003887
# 3                       69.7401                    -0.244233
# 4                       22.5828                     0.114681
# 5                       28.3301                    -0.019719
# 6                       65.1695                     0.000574
# 7                      129.1224                    -0.131551
# 8                       84.6637                    -0.028193
# 9                       64.8639                     0.305314
# 10                      33.2818                    -0.496589
# 11                      62.0404                     0.535887
# 12                      82.2567                    -0.179541
# 13                      79.9214                     0.113050
# 14                      34.6173                    -0.067384
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       1.040447                     0.544707
# 1                      -2.466679                    -1.673243
# 2                       0.043773                     0.083385
# 3                       0.148628                     1.059937
# 4                      -1.154383                    -2.270584
# 5                       0.928123                    -4.582275
# 6                       0.002529                    -0.012962
# 7                      -0.759161                    -8.101708
# 8                       2.140764                     3.914335
# 9                       0.569122                    -3.659274
# 10                      1.075666                     7.322047
# 11                      2.934326                    -3.203313
# 12                     -0.028355                    -3.104641
# 13                     -1.479350                     0.898437
# 14                     -0.158348                    -6.282417
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                       8.515964                     34.783368
# 1                      38.512815                     63.038985
# 2                       0.055094                      0.136289
# 3                       2.617150                     16.676327
# 4                       8.069417                     17.747688
# 5                       3.454435                     43.798719
# 6                      -0.019292                     -0.017112
# 7                       6.614696                     23.997119
# 8                      13.263861                     22.810568
# 9                       0.871428                     17.572930
# 10                     66.432410                    223.368370
# 11                     -2.296980                     59.507106
# 12                      0.153621                     21.177853
# 13                      3.453317                      1.044000
# 14                      3.043362                     20.709432
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      21.954113          2.085942e+12
# 1                      14.764857          3.022892e+11
# 2                       0.112789          1.542385e+11
# 3                      -6.659052          1.279727e+11
# 4                       8.291709          9.120436e+10
# 5                      10.616062          7.899366e+10
# 6                      -0.010852          6.102660e+10
# 7                      -5.857061          2.708449e+10
# 8                      13.079449          2.647249e+10
# 9                     -17.692905          2.357258e+10
# 10                    121.043549          1.159010e+10
# 11                     27.232532          1.082459e+10
# 12                    -11.156332          8.906705e+09
# 13                     -8.085731          8.322753e+09
# 14                     -4.061451          8.313822e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          63.6766                        2.203995e+12
# 1                           9.2278                        3.022892e+11
# 2                           4.7084                        1.561200e+11
# 3                           3.9066                        2.175606e+11
# 4                           2.7842                        9.120436e+10
# 5                           2.4114                        9.079802e+10
# 6                           1.8629                        6.102660e+10
# 7                           0.8268                        2.708449e+10
# 8                           0.8081                        2.647250e+10
# 9                           0.7196                        3.001421e+10
# 10                          0.3538                        3.470838e+10
# 11                          0.3304                        3.186822e+10
# 12                          0.2719                        1.355457e+10
# 13                          0.2541                        8.881171e+09
# 14                          0.2538                        1.410940e+10
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2025-06-06T16:44:00.000Z          NaN           NaN
# 1           None  2025-06-06T16:45:00.000Z          NaN           NaN
# 2           None  2025-06-06T16:44:00.000Z       1027.0      Ethereum
# 3           None  2025-06-06T16:45:00.000Z          NaN           NaN
# 4           None  2025-06-06T16:44:00.000Z          NaN           NaN
# 5           None  2025-06-06T16:44:00.000Z          NaN           NaN
# 6           None  2025-06-06T16:45:00.000Z       1027.0      Ethereum
# 7           None  2025-06-06T16:44:00.000Z          NaN           NaN
# 8           None  2025-06-06T16:44:00.000Z          NaN           NaN
# 9           None  2025-06-06T16:45:00.000Z          NaN           NaN
# 10          None  2025-06-06T16:44:00.000Z      32196.0   Hyperliquid
# 11          None  2025-06-06T16:45:00.000Z          NaN           NaN
# 12          None  2025-06-06T16:45:00.000Z       1027.0      Ethereum
# 13          None  2025-06-06T16:44:00.000Z       1027.0      Ethereum
# 14          None  2025-06-06T16:45:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              NaN           NaN                                         NaN
# 6              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10            HYPE   hyperliquid          0x0d01dc56dcaaca66ad901c959b4011ec
# 11             NaN           NaN                                         NaN
# 12             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 13             ETH      ethereum  0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3
# 14             NaN           NaN                                         NaN
#
#                     timestamp
# 0  2025-06-06 22:16:11.324227
# 1  2025-06-06 22:16:11.324227
# 2  2025-06-06 22:16:11.324227
# 3  2025-06-06 22:16:11.324227
# 4  2025-06-06 22:16:11.324227
# 5  2025-06-06 22:16:11.324227
# 6  2025-06-06 22:16:11.324227
# 7  2025-06-06 22:16:11.324227
# 8  2025-06-06 22:16:11.324227
# 9  2025-06-06 22:16:11.324227
# 10 2025-06-06 22:16:11.324227
# 11 2025-06-06 22:16:11.324227
# 12 2025-06-06 22:16:11.324227
# 13 2025-06-06 22:16:11.324227
# 14 2025-06-06 22:16:11.324227

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)

#NOTE:
# I had to go in and put "jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10"
# Into the Anaconda Prompt to change this to allow to pull data
    
    # Use this if you just want to keep it in a dataframe
    df2 = pd.json_normalize(data['data'])
    df2['Timestamp'] = pd.to_datetime('now')
    df2 = pd.concat([df2,df],ignore_index=True)


    # Use this if you want to create a csv and append data to it
    df = pd.json_normalize(data['data'])
    df['timestamp'] = pd.to_datetime('now')
    df

    if not os.path.isfile(r'C:\Python311\Scripts\API4.csv'):
        df.to_csv(r'C:\Python311\Scripts\API4.csv', header='column_names')
    else:
        df.to_csv(r'C:\Python311\Scripts\API4.csv', mode='a', header=False)
        


# If that didn't work try using the local host URL as shown in the video

# %%
import os 
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60) #sleep for 1 minute
exit()
# Out:
# API Runner completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[77], line 8
#       6     api_runner()
#       7     print('API Runner completed')
# ----> 8     sleep(60) #sleep for 1 minute
#       9 exit()
#
# KeyboardInterrupt:

# %%
df72 = pd.read_csv(r'C:\Python311\Scripts\API4.csv')
df72
# Out:
#     Unnamed: 0     id          name symbol          slug  num_market_pairs  \
# 0            0      1       Bitcoin    BTC       bitcoin             12210
# 1            1   1027      Ethereum    ETH      ethereum             10331
# 2            2    825   Tether USDt   USDT        tether            131931
# 3            3     52           XRP    XRP           xrp              1623
# 4            4   1839           BNB    BNB           bnb              2566
# 5            5   5426        Solana    SOL        solana               933
# 6            6   3408          USDC   USDC      usd-coin             28504
# 7            7     74      Dogecoin   DOGE      dogecoin              1234
# 8            8   1958          TRON    TRX          tron              1183
# 9            9   2010       Cardano    ADA       cardano              1529
# 10          10  32196   Hyperliquid   HYPE   hyperliquid               105
# 11          11  20947           Sui    SUI           sui               672
# 12          12   1975     Chainlink   LINK     chainlink              2020
# 13          13   5805     Avalanche   AVAX     avalanche               920
# 14          14   3957  UNUS SED LEO    LEO  unus-sed-leo                61
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2013-08-04T00:00:00.000Z
# 4   2017-07-25T00:00:00.000Z
# 5   2020-04-10T00:00:00.000Z
# 6   2018-10-08T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2017-09-13T00:00:00.000Z
# 9   2017-10-01T00:00:00.000Z
# 10  2024-07-15T10:14:50.000Z
# 11  2022-07-12T08:03:11.000Z
# 12  2017-09-20T00:00:00.000Z
# 13  2020-07-13T00:00:00.000Z
# 14  2019-05-21T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   ['mineable', 'pow', 'sha-256', 'store-of-value...  2.100000e+07
# 1   ['pos', 'smart-contracts', 'ethereum-ecosystem...           NaN
# 2   ['stablecoin', 'asset-backed-stablecoin', 'usd...           NaN
# 3   ['medium-of-exchange', 'enterprise-solutions',...  1.000000e+11
# 4   ['marketplace', 'centralized-exchange', 'payme...           NaN
# 5   ['pos', 'platform', 'solana-ecosystem', 'cms-h...           NaN
# 6   ['medium-of-exchange', 'stablecoin', 'asset-ba...           NaN
# 7   ['mineable', 'pow', 'scrypt', 'medium-of-excha...           NaN
# 8   ['media', 'payments', 'tron-ecosystem', 'layer...           NaN
# 9   ['dpos', 'pos', 'platform', 'research', 'smart...  4.500000e+10
# 10  ['decentralized-exchange-dex-token', 'defi', '...  1.000000e+09
# 11  ['binance-launchpool', 'coinbase-ventures-port...  1.000000e+10
# 12  ['platform', 'defi', 'oracles', 'smart-contrac...           NaN
# 13  ['smart-contracts', 'three-arrows-capital-port...  7.157487e+08
# 14  ['marketplace', 'centralized-exchange', 'disco...           NaN
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.987542e+07  1.987542e+07            False       NaN         1
# 1         1.207218e+08  1.207218e+08             True       NaN         2
# 2         1.544683e+11  1.560037e+11             True       NaN         3
# 3         5.882165e+10  9.998606e+10            False       NaN         4
# 4         1.408871e+08  1.408871e+08            False       NaN         5
# 5         5.248146e+08  6.025598e+08             True       NaN         6
# 6         6.111526e+10  6.111526e+10            False       NaN         7
# 7         1.495837e+11  1.495837e+11             True       NaN         8
# 8         9.485335e+10  9.485336e+10             True       NaN         9
# 9         3.534213e+10  4.499459e+10            False       NaN        10
# 10        3.339282e+08  9.999939e+08            False       NaN        11
# 11        3.396671e+09  1.000000e+10            False       NaN        12
# 12        6.571000e+08  1.000000e+09            False       NaN        13
# 13        4.217495e+08  4.567522e+08            False       NaN        14
# 14        9.232866e+08  9.852395e+08            False       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap  tvl_ratio  \
# 0                                NaN                       NaN        NaN
# 1                                NaN                       NaN        NaN
# 2                                NaN                       NaN        NaN
# 3                                NaN                       NaN        NaN
# 4                                NaN                       NaN        NaN
# 5                                NaN                       NaN        NaN
# 6                       6.090122e+10              6.089430e+10        NaN
# 7                                NaN                       NaN        NaN
# 8                                NaN                       NaN        NaN
# 9                                NaN                       NaN        NaN
# 10                      3.339317e+08              1.133741e+10        NaN
# 11                      3.396671e+09              1.115718e+10        NaN
# 12                               NaN                       NaN        NaN
# 13                               NaN                       NaN        NaN
# 14                               NaN                       NaN        NaN
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2025-06-07T08:09:00.000Z    104987.610088          4.565547e+10
# 1   2025-06-07T08:10:00.000Z      2492.266254          1.611908e+10
# 2   2025-06-07T08:09:00.000Z         1.000661          6.553776e+10
# 3   2025-06-07T08:10:00.000Z         2.185373          1.797464e+09
# 4   2025-06-07T08:09:00.000Z       649.326578          1.605461e+09
# 5   2025-06-07T08:09:00.000Z       152.640262          2.636745e+09
# 6   2025-06-07T08:09:00.000Z         0.999886          8.834269e+09
# 7   2025-06-07T08:09:00.000Z         0.185675          1.026067e+09
# 8   2025-06-07T08:09:00.000Z         0.278404          4.396894e+08
# 9   2025-06-07T08:10:00.000Z         0.669840          5.839582e+08
# 10  2025-06-07T08:10:00.000Z        33.951297          2.278857e+08
# 11  2025-06-07T08:09:00.000Z         3.284740          9.358249e+08
# 12  2025-06-07T08:10:00.000Z        14.039583          3.258333e+08
# 13  2025-06-07T08:10:00.000Z        20.758608          2.952095e+08
# 14  2025-06-07T08:09:00.000Z         9.079076          4.052528e+06
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                      -26.3796                    -0.120342
# 1                      -43.1658                    -0.048832
# 2                      -33.5510                     0.006320
# 3                      -48.1172                    -0.063655
# 4                      -24.3273                    -0.025557
# 5                      -42.4662                     0.417652
# 6                      -39.3511                     0.003601
# 7                      -48.5571                     0.684882
# 8                      -51.5827                     0.151812
# 9                      -37.6064                     0.300960
# 10                     -40.7033                    -0.569486
# 11                     -24.8671                     0.267279
# 12                     -28.8988                     0.337969
# 13                     -37.7559                     1.737580
# 14                      -9.8877                     0.013234
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       1.544280                     1.174586
# 1                       1.215713                    -1.269128
# 2                       0.021687                     0.031683
# 3                       2.312052                     2.495891
# 4                       1.200544                    -0.736041
# 5                       3.392766                    -1.526036
# 6                      -0.006533                     0.001554
# 7                       5.822887                    -2.095982
# 8                       0.688641                     3.438114
# 9                       4.287928                     0.545020
# 10                     -2.573500                     7.838517
# 11                      8.596688                     3.383866
# 12                      6.326475                     2.096884
# 13                      6.943988                     2.759827
# 14                      2.703364                     3.781503
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                       5.506302                     32.452682
# 1                      29.260316                     59.428001
# 2                       0.032103                      0.056780
# 3                      -0.364398                     17.386028
# 4                       5.526256                     16.209181
# 5                       0.252902                     40.957396
# 6                      -0.033873                     -0.062544
# 7                       1.991137                     23.520480
# 8                      11.055729                     18.832805
# 9                      -5.826841                     14.918093
# 10                     55.254642                    186.428101
# 11                    -10.137769                     62.345910
# 12                     -4.815543                     21.475395
# 13                     -0.947422                     22.410333
# 14                      3.439766                      1.160772
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      22.167989          2.086672e+12
# 1                      14.292579          3.008708e+11
# 2                       0.091536          1.545704e+11
# 3                      -6.360014          1.285472e+11
# 4                      10.936546          9.148174e+10
# 5                       9.530730          8.010783e+10
# 6                       0.002011          6.110832e+10
# 7                      -2.742331          2.777399e+10
# 8                      15.183366          2.640753e+10
# 9                     -17.542991          2.367356e+10
# 10                    122.993604          1.133729e+10
# 11                     30.943239          1.115718e+10
# 12                     -6.990855          9.225410e+09
# 13                      3.398563          8.754932e+09
# 14                     -6.981968          8.382590e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          63.6503                        2.204740e+12
# 1                           9.1775                        3.008708e+11
# 2                           4.7149                        1.561068e+11
# 3                           3.9211                        2.185373e+11
# 4                           2.7905                        9.148174e+10
# 5                           2.4435                        9.197489e+10
# 6                           1.8640                        6.110832e+10
# 7                           0.8472                        2.777399e+10
# 8                           0.8055                        2.640753e+10
# 9                           0.7221                        3.014278e+10
# 10                          0.3458                        3.395130e+10
# 11                          0.3403                        3.284740e+10
# 12                          0.2814                        1.403958e+10
# 13                          0.2671                        1.485795e+10
# 14                          0.2557                        8.945065e+09
#
#     quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0             NaN  2025-06-07T08:09:00.000Z          NaN           NaN
# 1             NaN  2025-06-07T08:10:00.000Z          NaN           NaN
# 2             NaN  2025-06-07T08:09:00.000Z       1027.0      Ethereum
# 3             NaN  2025-06-07T08:10:00.000Z          NaN           NaN
# 4             NaN  2025-06-07T08:09:00.000Z          NaN           NaN
# 5             NaN  2025-06-07T08:09:00.000Z          NaN           NaN
# 6             NaN  2025-06-07T08:09:00.000Z       1027.0      Ethereum
# 7             NaN  2025-06-07T08:09:00.000Z          NaN           NaN
# 8             NaN  2025-06-07T08:09:00.000Z          NaN           NaN
# 9             NaN  2025-06-07T08:10:00.000Z          NaN           NaN
# 10            NaN  2025-06-07T08:10:00.000Z      32196.0   Hyperliquid
# 11            NaN  2025-06-07T08:09:00.000Z          NaN           NaN
# 12            NaN  2025-06-07T08:10:00.000Z       1027.0      Ethereum
# 13            NaN  2025-06-07T08:10:00.000Z          NaN           NaN
# 14            NaN  2025-06-07T08:09:00.000Z       1027.0      Ethereum
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              NaN           NaN                                         NaN
# 6              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10            HYPE   hyperliquid          0x0d01dc56dcaaca66ad901c959b4011ec
# 11             NaN           NaN                                         NaN
# 12             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 13             NaN           NaN                                         NaN
# 14             ETH      ethereum  0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3
#
#                      timestamp
# 0   2025-06-07 13:41:06.887899
# 1   2025-06-07 13:41:06.887899
# 2   2025-06-07 13:41:06.887899
# 3   2025-06-07 13:41:06.887899
# 4   2025-06-07 13:41:06.887899
# 5   2025-06-07 13:41:06.887899
# 6   2025-06-07 13:41:06.887899
# 7   2025-06-07 13:41:06.887899
# 8   2025-06-07 13:41:06.887899
# 9   2025-06-07 13:41:06.887899
# 10  2025-06-07 13:41:06.887899
# 11  2025-06-07 13:41:06.887899
# 12  2025-06-07 13:41:06.887899
# 13  2025-06-07 13:41:06.887899
# 14  2025-06-07 13:41:06.887899

# %%
df

# %%
# One thing I noticed was the scientific notation. I like it, but I want to be able to see the numbers in this case

pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df

# %%
# Now let's look at the coin trends over time

df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#               quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                          -0.12034                       1.54428
# Ethereum                         -0.04883                       1.21571
# Tether USDt                       0.00632                       0.02169
# XRP                              -0.06365                       2.31205
# BNB                              -0.02556                       1.20054
# Solana                            0.41765                       3.39277
# USDC                              0.00360                      -0.00653
# Dogecoin                          0.68488                       5.82289
# TRON                              0.15181                       0.68864
# Cardano                           0.30096                       4.28793
# Hyperliquid                      -0.56949                      -2.57350
# Sui                               0.26728                       8.59669
# Chainlink                         0.33797                       6.32648
# Avalanche                         1.73758                       6.94399
# UNUS SED LEO                      0.01323                       2.70336
#
#               quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# name
# Bitcoin                           1.17459                       5.50630
# Ethereum                         -1.26913                      29.26032
# Tether USDt                       0.03168                       0.03210
# XRP                               2.49589                      -0.36440
# BNB                              -0.73604                       5.52626
# Solana                           -1.52604                       0.25290
# USDC                              0.00155                      -0.03387
# Dogecoin                         -2.09598                       1.99114
# TRON                              3.43811                      11.05573
# Cardano                           0.54502                      -5.82684
# Hyperliquid                       7.83852                      55.25464
# Sui                               3.38387                     -10.13777
# Chainlink                         2.09688                      -4.81554
# Avalanche                         2.75983                      -0.94742
# UNUS SED LEO                      3.78150                       3.43977
#
#               quote.USD.percent_change_60d  quote.USD.percent_change_90d
# name
# Bitcoin                           32.45268                      22.16799
# Ethereum                          59.42800                      14.29258
# Tether USDt                        0.05678                       0.09154
# XRP                               17.38603                      -6.36001
# BNB                               16.20918                      10.93655
# Solana                            40.95740                       9.53073
# USDC                              -0.06254                       0.00201
# Dogecoin                          23.52048                      -2.74233
# TRON                              18.83281                      15.18337
# Cardano                           14.91809                     -17.54299
# Hyperliquid                      186.42810                     122.99360
# Sui                               62.34591                      30.94324
# Chainlink                         21.47540                      -6.99085
# Avalanche                         22.41033                       3.39856
# UNUS SED LEO                       1.16077                      -6.98197

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin       quote.USD.percent_change_1h     -0.12034
#               quote.USD.percent_change_24h     1.54428
#               quote.USD.percent_change_7d      1.17459
#               quote.USD.percent_change_30d     5.50630
#               quote.USD.percent_change_60d    32.45268
#               quote.USD.percent_change_90d    22.16799
# Ethereum      quote.USD.percent_change_1h     -0.04883
#               quote.USD.percent_change_24h     1.21571
#               quote.USD.percent_change_7d     -1.26913
#               quote.USD.percent_change_30d    29.26032
#               quote.USD.percent_change_60d    59.42800
#               quote.USD.percent_change_90d    14.29258
# Tether USDt   quote.USD.percent_change_1h      0.00632
#               quote.USD.percent_change_24h     0.02169
#               quote.USD.percent_change_7d      0.03168
#               quote.USD.percent_change_30d     0.03210
#               quote.USD.percent_change_60d     0.05678
#               quote.USD.percent_change_90d     0.09154
# XRP           quote.USD.percent_change_1h     -0.06365
#               quote.USD.percent_change_24h     2.31205
#               quote.USD.percent_change_7d      2.49589
#               quote.USD.percent_change_30d    -0.36440
#               quote.USD.percent_change_60d    17.38603
#               quote.USD.percent_change_90d    -6.36001
# BNB           quote.USD.percent_change_1h     -0.02556
#               quote.USD.percent_change_24h     1.20054
#               quote.USD.percent_change_7d     -0.73604
#               quote.USD.percent_change_30d     5.52626
#               quote.USD.percent_change_60d    16.20918
#               quote.USD.percent_change_90d    10.93655
# Solana        quote.USD.percent_change_1h      0.41765
#               quote.USD.percent_change_24h     3.39277
#               quote.USD.percent_change_7d     -1.52604
#               quote.USD.percent_change_30d     0.25290
#               quote.USD.percent_change_60d    40.95740
#               quote.USD.percent_change_90d     9.53073
# USDC          quote.USD.percent_change_1h      0.00360
#               quote.USD.percent_change_24h    -0.00653
#               quote.USD.percent_change_7d      0.00155
#               quote.USD.percent_change_30d    -0.03387
#               quote.USD.percent_change_60d    -0.06254
#               quote.USD.percent_change_90d     0.00201
# Dogecoin      quote.USD.percent_change_1h      0.68488
#               quote.USD.percent_change_24h     5.82289
#               quote.USD.percent_change_7d     -2.09598
#               quote.USD.percent_change_30d     1.99114
#               quote.USD.percent_change_60d    23.52048
#               quote.USD.percent_change_90d    -2.74233
# TRON          quote.USD.percent_change_1h      0.15181
#               quote.USD.percent_change_24h     0.68864
#               quote.USD.percent_change_7d      3.43811
#               quote.USD.percent_change_30d    11.05573
#               quote.USD.percent_change_60d    18.83281
#               quote.USD.percent_change_90d    15.18337
# Cardano       quote.USD.percent_change_1h      0.30096
#               quote.USD.percent_change_24h     4.28793
#               quote.USD.percent_change_7d      0.54502
#               quote.USD.percent_change_30d    -5.82684
#               quote.USD.percent_change_60d    14.91809
#               quote.USD.percent_change_90d   -17.54299
# Hyperliquid   quote.USD.percent_change_1h     -0.56949
#               quote.USD.percent_change_24h    -2.57350
#               quote.USD.percent_change_7d      7.83852
#               quote.USD.percent_change_30d    55.25464
#               quote.USD.percent_change_60d   186.42810
#               quote.USD.percent_change_90d   122.99360
# Sui           quote.USD.percent_change_1h      0.26728
#               quote.USD.percent_change_24h     8.59669
#               quote.USD.percent_change_7d      3.38387
#               quote.USD.percent_change_30d   -10.13777
#               quote.USD.percent_change_60d    62.34591
#               quote.USD.percent_change_90d    30.94324
# Chainlink     quote.USD.percent_change_1h      0.33797
#               quote.USD.percent_change_24h     6.32648
#               quote.USD.percent_change_7d      2.09688
#               quote.USD.percent_change_30d    -4.81554
#               quote.USD.percent_change_60d    21.47540
#               quote.USD.percent_change_90d    -6.99085
# Avalanche     quote.USD.percent_change_1h      1.73758
#               quote.USD.percent_change_24h     6.94399
#               quote.USD.percent_change_7d      2.75983
#               quote.USD.percent_change_30d    -0.94742
#               quote.USD.percent_change_60d    22.41033
#               quote.USD.percent_change_90d     3.39856
# UNUS SED LEO  quote.USD.percent_change_1h      0.01323
#               quote.USD.percent_change_24h     2.70336
#               quote.USD.percent_change_7d      3.78150
#               quote.USD.percent_change_30d     3.43977
#               quote.USD.percent_change_60d     1.16077
#               quote.USD.percent_change_90d    -6.98197
# dtype: float64

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                              values
# name
# Bitcoin      quote.USD.percent_change_1h   -0.12034
#              quote.USD.percent_change_24h   1.54428
#              quote.USD.percent_change_7d    1.17459
#              quote.USD.percent_change_30d   5.50630
#              quote.USD.percent_change_60d  32.45268
#              quote.USD.percent_change_90d  22.16799
# Ethereum     quote.USD.percent_change_1h   -0.04883
#              quote.USD.percent_change_24h   1.21571
#              quote.USD.percent_change_7d   -1.26913
#              quote.USD.percent_change_30d  29.26032
#              quote.USD.percent_change_60d  59.42800
#              quote.USD.percent_change_90d  14.29258
# Tether USDt  quote.USD.percent_change_1h    0.00632
#              quote.USD.percent_change_24h   0.02169
#              quote.USD.percent_change_7d    0.03168
#              quote.USD.percent_change_30d   0.03210
#              quote.USD.percent_change_60d   0.05678
#              quote.USD.percent_change_90d   0.09154
# XRP          quote.USD.percent_change_1h   -0.06365
#              quote.USD.percent_change_24h   2.31205
#              quote.USD.percent_change_7d    2.49589
#              quote.USD.percent_change_30d  -0.36440
#              quote.USD.percent_change_60d  17.38603
#              quote.USD.percent_change_90d  -6.36001
# BNB          quote.USD.percent_change_1h   -0.02556
#              quote.USD.percent_change_24h   1.20054
#              quote.USD.percent_change_7d   -0.73604
#              quote.USD.percent_change_30d   5.52626
#              quote.USD.percent_change_60d  16.20918
#              quote.USD.percent_change_90d  10.93655
# Solana       quote.USD.percent_change_1h    0.41765
#              quote.USD.percent_change_24h   3.39277
#              quote.USD.percent_change_7d   -1.52604
#              quote.USD.percent_change_30d   0.25290
#              quote.USD.percent_change_60d  40.95740
#              quote.USD.percent_change_90d   9.53073
# USDC         quote.USD.percent_change_1h    0.00360
#              quote.USD.percent_change_24h  -0.00653
#              quote.USD.percent_change_7d    0.00155
#              quote.USD.percent_change_30d  -0.03387
#              quote.USD.percent_change_60d  -0.06254
#              quote.USD.percent_change_90d   0.00201
# Dogecoin     quote.USD.percent_change_1h    0.68488
#              quote.USD.percent_change_24h   5.82289
#              quote.USD.percent_change_7d   -2.09598
#              quote.USD.percent_change_30d   1.99114
#              quote.USD.percent_change_60d  23.52048
#              quote.USD.percent_change_90d  -2.74233
# TRON         quote.USD.percent_change_1h    0.15181
#              quote.USD.percent_change_24h   0.68864
#              quote.USD.percent_change_7d    3.43811
#              quote.USD.percent_change_30d  11.05573
#              quote.USD.percent_change_60d  18.83281
#              quote.USD.percent_change_90d  15.18337
# Cardano      quote.USD.percent_change_1h    0.30096
#              quote.USD.percent_change_24h   4.28793
#              quote.USD.percent_change_7d    0.54502
#              quote.USD.percent_change_30d  -5.82684
#              quote.USD.percent_change_60d  14.91809
#              quote.USD.percent_change_90d -17.54299
# Hyperliquid  quote.USD.percent_change_1h   -0.56949
#              quote.USD.percent_change_24h  -2.57350
#              quote.USD.percent_change_7d    7.83852
#              quote.USD.percent_change_30d  55.25464
#              quote.USD.percent_change_60d 186.42810
#              quote.USD.percent_change_90d 122.99360
# Sui          quote.USD.percent_change_1h    0.26728
#              quote.USD.percent_change_24h   8.59669
#              quote.USD.percent_change_7d    3.38387
#              quote.USD.percent_change_30d -10.13777
#              quote.USD.percent_change_60d  62.34591
#              quote.USD.percent_change_90d  30.94324
# Chainlink    quote.USD.percent_change_1h    0.33797
#              quote.USD.percent_change_24h   6.32648
#              quote.USD.percent_change_7d    2.09688
#              quote.USD.percent_change_30d  -4.81554
#              quote.USD.percent_change_60d  21.47540
#              quote.USD.percent_change_90d  -6.99085
# Avalanche    quote.USD.percent_change_1h    1.73758
#              quote.USD.percent_change_24h   6.94399
#              quote.USD.percent_change_7d    2.75983
#              quote.USD.percent_change_30d  -0.94742
#              quote.USD.percent_change_60d  22.41033
#              quote.USD.percent_change_90d   3.39856
# UNUS SED LEO quote.USD.percent_change_1h    0.01323
#              quote.USD.percent_change_24h   2.70336
#              quote.USD.percent_change_7d    3.78150
#              quote.USD.percent_change_30d   3.43977
#              quote.USD.percent_change_60d   1.16077
#              quote.USD.percent_change_90d  -6.98197

# %%
df5.count()

# %%
#Because of how it's structured above we need to set an index. I don't want to pass a column as an index for this dataframe
#So I'm going to create a range and pass that as the dataframe. You can make this more dynamic, but I'm just going to hard code it


index = pd.Index(range(90))

# Set the above DataFrame index object as the index
# using set_index() function
df6 = df5.set_index(index)
df6

# If it only has the index and values try doing reset_index like "df5.reset_index()"
# Out:
#       values
# 0   -0.12034
# 1    1.54428
# 2    1.17459
# 3    5.50630
# 4   32.45268
# 5   22.16799
# 6   -0.04883
# 7    1.21571
# 8   -1.26913
# 9   29.26032
# 10  59.42800
# 11  14.29258
# 12   0.00632
# 13   0.02169
# 14   0.03168
# 15   0.03210
# 16   0.05678
# 17   0.09154
# 18  -0.06365
# 19   2.31205
# 20   2.49589
# 21  -0.36440
# 22  17.38603
# 23  -6.36001
# 24  -0.02556
# 25   1.20054
# 26  -0.73604
# 27   5.52626
# 28  16.20918
# 29  10.93655
# 30   0.41765
# 31   3.39277
# 32  -1.52604
# 33   0.25290
# 34  40.95740
# 35   9.53073
# 36   0.00360
# 37  -0.00653
# 38   0.00155
# 39  -0.03387
# 40  -0.06254
# 41   0.00201
# 42   0.68488
# 43   5.82289
# 44  -2.09598
# 45   1.99114
# 46  23.52048
# 47  -2.74233
# 48   0.15181
# 49   0.68864
# 50   3.43811
# 51  11.05573
# 52  18.83281
# 53  15.18337
# 54   0.30096
# 55   4.28793
# 56   0.54502
# 57  -5.82684
# 58  14.91809
# 59 -17.54299
# 60  -0.56949
# 61  -2.57350
# 62   7.83852
# 63  55.25464
# 64 186.42810
# 65 122.99360
# 66   0.26728
# 67   8.59669
# 68   3.38387
# 69 -10.13777
# 70  62.34591
# 71  30.94324
# 72   0.33797
# 73   6.32648
# 74   2.09688
# 75  -4.81554
# 76  21.47540
# 77  -6.99085
# 78   1.73758
# 79   6.94399
# 80   2.75983
# 81  -0.94742
# 82  22.41033
# 83   3.39856
# 84   0.01323
# 85   2.70336
# 86   3.78150
# 87   3.43977
# 88   1.16077
# 89  -6.98197

# %%
# Change the column name

df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#       values
# 0   -0.12034
# 1    1.54428
# 2    1.17459
# 3    5.50630
# 4   32.45268
# 5   22.16799
# 6   -0.04883
# 7    1.21571
# 8   -1.26913
# 9   29.26032
# 10  59.42800
# 11  14.29258
# 12   0.00632
# 13   0.02169
# 14   0.03168
# 15   0.03210
# 16   0.05678
# 17   0.09154
# 18  -0.06365
# 19   2.31205
# 20   2.49589
# 21  -0.36440
# 22  17.38603
# 23  -6.36001
# 24  -0.02556
# 25   1.20054
# 26  -0.73604
# 27   5.52626
# 28  16.20918
# 29  10.93655
# 30   0.41765
# 31   3.39277
# 32  -1.52604
# 33   0.25290
# 34  40.95740
# 35   9.53073
# 36   0.00360
# 37  -0.00653
# 38   0.00155
# 39  -0.03387
# 40  -0.06254
# 41   0.00201
# 42   0.68488
# 43   5.82289
# 44  -2.09598
# 45   1.99114
# 46  23.52048
# 47  -2.74233
# 48   0.15181
# 49   0.68864
# 50   3.43811
# 51  11.05573
# 52  18.83281
# 53  15.18337
# 54   0.30096
# 55   4.28793
# 56   0.54502
# 57  -5.82684
# 58  14.91809
# 59 -17.54299
# 60  -0.56949
# 61  -2.57350
# 62   7.83852
# 63  55.25464
# 64 186.42810
# 65 122.99360
# 66   0.26728
# 67   8.59669
# 68   3.38387
# 69 -10.13777
# 70  62.34591
# 71  30.94324
# 72   0.33797
# 73   6.32648
# 74   2.09688
# 75  -4.81554
# 76  21.47540
# 77  -6.99085
# 78   1.73758
# 79   6.94399
# 80   2.75983
# 81  -0.94742
# 82  22.41033
# 83   3.39856
# 84   0.01323
# 85   2.70336
# 86   3.78150
# 87   3.43977
# 88   1.16077
# 89  -6.98197

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['24h','7d','30d','60d','90d'])
df7
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File E:\anaconda\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'percent_change'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['24h','7d','30d','60d','90d'])
#       2 df7
#
# File E:\anaconda\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File E:\anaconda\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'percent_change'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')
#
# File E:\anaconda\Lib\site-packages\seaborn\categorical.py:2782, in catplot(data, x, y, hue, row, col, kind, estimator, errorbar, n_boot, seed, units, weights, order, hue_order, row_order, col_order, col_wrap, height, aspect, log_scale, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    2779     elif x is not None and y is not None:
#    2780         raise ValueError("Cannot pass values for both `x` and `y`.")
# -> 2782 p = Plotter(
#    2783     data=data,
#    2784     variables=dict(
#    2785         x=x, y=y, hue=hue, row=row, col=col, units=units, weight=weights
#    2786     ),
#    2787     order=order,
#    2788     orient=orient,
#    2789     # Handle special backwards compatibility where pointplot originally
#    2790     # did *not* default to multi-colored unless a palette was specified.
#    2791     color="C0" if kind == "point" and palette is None and color is None else color,
#    2792     legend=legend,
#    2793 )
#    2795 for var in ["row", "col"]:
#    2796     # Handle faceting variables that lack name information
#    2797     if var in p.variables and p.variables[var] is None:
#
# File E:\anaconda\Lib\site-packages\seaborn\categorical.py:67, in _CategoricalPlotter.__init__(self, data, variables, order, orient, require_numeric, color, legend)
#      56 def __init__(
#      57     self,
#      58     data=None,
#    (...)
#      64     legend="auto",
#      65 ):
# ---> 67     super().__init__(data=data, variables=variables)
#      69     # This method takes care of some bookkeeping that is necessary because the
#      70     # original categorical plots (prior to the 2021 refactor) had some rules that
#      71     # don't fit exactly into VectorPlotter logic. It may be wise to have a second
#    (...)
#      76     # default VectorPlotter rules. If we do decide to make orient part of the
#      77     # _base variable assignment, we'll want to figure out how to express that.
#      78     if self.input_format == "wide" and orient in ["h", "y"]:
#
# File E:\anaconda\Lib\site-packages\seaborn\_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File E:\anaconda\Lib\site-packages\seaborn\_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File E:\anaconda\Lib\site-packages\seaborn\_core\data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File E:\anaconda\Lib\site-packages\seaborn\_core\data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `percent_change` for `x`. An entry with this name does not appear in `data`.

# %%
# Now to do something much simpler
# we are going to create a dataframe with the columns we want

df10 = df[['name','quote.USD.price','timestamp']]
df10 = df10.query("name == 'Bitcoin'")
df10

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x='timestamp', y='quote.USD.price', data = df10)
